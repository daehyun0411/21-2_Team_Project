# %%
import pandas as pd
import numpy as np

# %%
cab = pd.read_csv('C:/Users/keogu/Downloads/235801_2021 농산물 가격예측 AI 경진대회/public_data/train_AT_TSALET_ALL/AT_TSALET_ALL_201601.csv')

# %%
cab2 = pd.read_csv('C:/Users/keogu/Downloads/갓.csv')
# Out:
# C:\Users\keogu\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
cab2
# Out:
#        PUM_NM LV_NM   TOT_AMT    SAN_NM  SALEDATE CMP_NM DAN_NM WHSAL_NM  \
# 0           갓     .  120000.0       NaN  20140103   서울청과     kg   서울가락도매
# 1           갓     .  150000.0       NaN  20140103   서울청과     kg   서울가락도매
# 2           갓     .   70000.0   경기도 고양시  20140103   서울청과     kg   서울가락도매
# 3           갓     특   10000.0  전라남도 무안군  20140103   중앙청과     kg   서울가락도매
# 4           갓     특  180000.0   경기도 고양시  20140103   동화청과     kg   서울가락도매
# ...       ...   ...       ...       ...       ...    ...    ...      ...
# 397040      갓     .  330000.0       NaN  20211030   강서청과     kg   서울강서도매
# 397041      갓     .  450000.0       NaN  20211030   강서청과     kg   서울강서도매
# 397042      갓     .  450000.0       NaN  20211030   강서청과     kg   서울강서도매
# 397043      갓     .  450000.0       NaN  20211030   강서청과     kg   서울강서도매
# 397044      갓     .  450000.0       NaN  20211030   강서청과     kg   서울강서도매
#
#          SIZE_NM     COST POJ_NM  TOT_QTY    QTY KIND_NM  DANQ
# ...

# %%
cab
# Out:
#          SALEDATE WHSAL_NM CMP_NM PUM_NM KIND_NM DAN_NM POJ_NM SIZE_NM LV_NM  \
# 0        20160109   부산엄궁도매   부산청과     감귤     조생귤     kg     상자       .    보통
# 1        20160109   부산엄궁도매   부산청과     감귤     조생귤     kg     상자       .    보통
# 2        20160109   부산엄궁도매   부산청과     감귤     조생귤     kg     상자       .     특
# 3        20160109   부산엄궁도매   부산청과     감귤     조생귤     kg     상자       .     특
# 4        20160109   부산엄궁도매   부산청과     감귤     조생귤     kg     상자       .    보통
# ...           ...      ...    ...    ...     ...    ...    ...     ...   ...
# 2700791  20160130   서울강서도매   강서청과      배      신고     kg      .       .     .
# 2700792  20160130   서울강서도매   강서청과      배      신고     kg      .       .     .
# 2700793  20160130   서울강서도매   강서청과      배      신고     kg      .       .     .
# 2700794  20160130   서울강서도매   강서청과      배      신고     kg      .       .     .
# 2700795  20160130   서울강서도매   강서청과      배      신고     kg      .       .     .
#
# ...

# %%
cab['PUM_NM'].unique()
# Out:
# array(['감귤', '만감', '오이', '쪽파', '브로코리(녹색꽃양배추)', '적채', '콜라비(순무양배추)', '고구마',
#        '감자', '대파', '호박', '딸기', '칼리플라워(꽃양배추)', '비트(붉은사탕무우)', '배추', '기타',
#        '부추', '무', '미나리', '양파', '우엉', '사과', '시금치', '쑥', '양상추', '상추',
#        '피망(단고추)', '가지', '오렌지', '레몬', '방아', '봄동배추', '열무', '참나물', '머위대',
#        '동초', '냉이', '토마토', '풋고추', '홍고추', '돗나물', '로메인', '청경채', '치커리', '근대',
#        '케일', '새송이', '팽이버섯', '만가닥', '느타리버섯', '생강', '마늘', '방울토마토', '꽈리고추',
#        '수박', '단감', '양송이', '표고버섯', '곶감', '쑥갓', '파세리(향미나리)', '셀러리(양미나리)',
#        '깻잎', '겨자채', '마', '연근', '도라지', '미역', '우뭇가사리', '취나물', '비타민', '새싹',
#        '파프리카', '당근', '양배추', '고수', '얼갈이배추', '유채', '달래', '고비', '고사리',
#        '조미제품', '곡물제조', '고구마순', '토란대', '갓', '무순', '전분 및 사료제조', '콩나물',
#        '숙주나물', '계피', '목이', '참깨', '바나나', '파인애플', '유지', '대추', '절임식품',
#        '조미가공', '다시마', '파래', '어묵_어분_어비', '차', '황기', '과루인(하늘타리)', '포도',
#        '아욱', '밤', '떫은감', '배', '겨자', '참당귀', '쌈추', '방울양배추(스프로스)', '속새',
# ...

# %%
import pandas as pd
import urllib.request
import json
import datetime

# %%
today = datetime.datetime.today()
yesterday = (today - datetime.timedelta(1)).strftime('%Y%m%d') 
url = 'https://www.nongnet.or.kr/api/whlslDstrQr.do?sdate=' # sdate = 날짜

response = urllib.request.urlopen(url+yesterday).read()
response = json.loads(response)

data = pd.DataFrame(response['data'])

# %%
data
# Out:
#        PUM_NM LV_NM  TOT_AMT  SAN_NM  SALEDATE CMP_NM DAN_NM WHSAL_NM SIZE_NM  \
# 0          단감     상   144600  경남 함안군  20211028   천안청과     kg   천안도매시장       .
# 1          단감     상    93000  경남 함안군  20211028   천안청과     kg   천안도매시장       .
# 2          단감     상    10200  경남 함안군  20211028   천안청과     kg   천안도매시장       .
# 3          단감     상   187500  경남 함안군  20211028   천안청과     kg   천안도매시장       .
# 4          단감     상   355000  경남 함안군  20211028   천안청과     kg   천안도매시장       .
# ...       ...   ...      ...     ...       ...    ...    ...      ...     ...
# 106714     기타     .    72000    None  20211028   강서청과     kg   서울강서도매       .
# 106715     기타     .   154000    None  20211028   강서청과     kg   서울강서도매       .
# 106716     기타     .   169000    None  20211028   강서청과     kg   서울강서도매       .
# 106717     기타     .    32000    None  20211028   강서청과     kg   서울강서도매       .
# 106718     기타     .    48000    None  20211028   강서청과     kg   서울강서도매       .
#
# ...
