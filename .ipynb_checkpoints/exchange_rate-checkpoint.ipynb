# %%
import pandas as pd

# %%
df = pd.read_excel("환율변동조회_20210928.xls")

# %%
df
# Out:
#                                                 환율변동조회 Unnamed: 1 Unnamed: 2  \
# 0                                                  NaN        NaN        NaN
# 1    기준일 : 2019-01-02 ~ 2021-09-28 통화 : 달러(미국) USD ...        NaN        NaN
# 2                                                   일자      현찰사실때      현찰파실때
# 3                                           2021-09-28    1206.24    1164.76
# 4                                           2021-09-27    1201.66    1160.34
# ..                                                 ...        ...        ...
# 677                                         2019-01-08     1145.7     1106.3
# 678                                         2019-01-07     1139.6     1100.4
# 679                                         2019-01-04    1143.67    1104.33
# 680                                         2019-01-03    1147.23    1107.77
# 681                                         2019-01-02    1142.14    1102.86
#
# ...

# %%
df.columns = df.iloc[2]

# %%
df.drop(index=[0,1,2], inplace=True)

# %%
df
# Out:
# 2            일자    현찰사실때    현찰파실때  송금보내실때  송금받으실때   T/C사실때  외화수표파실때   매매기준율  \
# 3    2021-09-28  1206.24  1164.76  1197.1  1173.9        0  1173.27  1185.5
# 4    2021-09-27  1201.66  1160.34  1192.5  1169.5        0  1168.87    1181
# 5    2021-09-24  1198.61  1157.39  1189.5  1166.5        0  1165.87    1178
# 6    2021-09-23  1194.54  1153.46  1185.5  1162.5        0  1161.87    1174
# 7    2021-09-17  1204.72  1163.28  1195.6  1172.4        0  1171.77    1184
# ..          ...      ...      ...     ...     ...      ...      ...     ...
# 677  2019-01-08   1145.7   1106.3    1137    1115  1139.51  1113.64    1126
# 678  2019-01-07   1139.6   1100.4  1130.9  1109.1  1133.44  1107.75    1120
# 679  2019-01-04  1143.67  1104.33    1135    1113  1137.48  1111.64    1124
# 680  2019-01-03  1147.23  1107.77  1138.5  1116.5  1141.03  1115.14  1127.5
# 681  2019-01-02  1142.14  1102.86  1133.5  1111.5  1135.97  1110.15  1122.5
#
# 2    직전대비     환가료율 미화환산율
# 3     4.5  1.93675     1
# ...

# %%
df['일자'] = pd.to_datetime(df['일자'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 679 entries, 2021-09-28 to 2019-01-02
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   현찰사실때    679 non-null    object
#  1   현찰파실때    679 non-null    object
#  2   송금보내실때   679 non-null    object
#  3   송금받으실때   679 non-null    object
#  4   T/C사실때   679 non-null    object
#  5   외화수표파실때  679 non-null    object
#  6   매매기준율    679 non-null    object
#  7   직전대비     679 non-null    object
#  8   환가료율     679 non-null    object
#  9   미화환산율    679 non-null    object
# dtypes: object(10)
# memory usage: 58.4+ KB

# %%
df = df.astype('float')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 679 entries, 2021-09-28 to 2019-01-02
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   현찰사실때    679 non-null    float64
#  1   현찰파실때    679 non-null    float64
#  2   송금보내실때   679 non-null    float64
#  3   송금받으실때   679 non-null    float64
#  4   T/C사실때   679 non-null    float64
#  5   외화수표파실때  679 non-null    float64
#  6   매매기준율    679 non-null    float64
#  7   직전대비     679 non-null    float64
#  8   환가료율     679 non-null    float64
#  9   미화환산율    679 non-null    float64
# dtypes: float64(10)
# memory usage: 58.4 KB

# %%
df.set_index(['일자'], inplace=True)

# %%
df = df.resample(rule='W').mean()

# %%
df
# Out:
# 2                 현찰사실때        현찰파실때       송금보내실때       송금받으실때    T/C사실때  \
# 일자
# 2019-01-06  1144.346667  1104.986667  1135.666667  1113.666667  1138.160
# 2019-01-13  1140.552000  1101.328000  1131.860000  1110.020000  1134.388
# 2019-01-20  1143.464000  1104.136000  1134.800000  1112.800000  1137.282
# 2019-01-27  1148.142000  1108.658000  1139.380000  1117.420000  1141.938
# 2019-02-03  1137.256000  1098.144000  1128.600000  1106.800000  1131.106
# ...                 ...          ...          ...          ...       ...
# 2021-09-05  1179.888000  1139.312000  1170.920000  1148.280000     0.000
# 2021-09-12  1185.586000  1144.814000  1176.560000  1153.840000     0.000
# 2021-09-19  1194.950000  1153.850000  1185.880000  1162.920000     0.000
# 2021-09-26  1196.575000  1155.425000  1187.500000  1164.500000     0.000
# 2021-10-03  1203.950000  1162.550000  1194.800000  1171.700000     0.000
#
# 2            외화수표파실때        매매기준율  직전대비      환가료율  미화환산율
# 일자
# ...
